# %%
from time import sleep
from vnpy.trader.engine import FeishuEngine

# %%
engine = FeishuEngine(None, None)

engine.send_feishu(
    webhook_url="https://open.feishu.cn/open-apis/bot/v2/hook/c476ec1f-6037-4e52-ad65-843e16201456",
    message={
        "msg_type": "text",
        "content": {"text": "机器人开发 - 测试消息"}
    },
    secret="pD6SEfuw75zNo74qxT5ZPb"
)
engine.send_feishu(
    webhook_url="https://open.feishu.cn/open-apis/bot/v2/hook/c476ec1f-6037-4e52-ad65-843e16201456",
    message={
        "msg_type": "text",
        "content": {"text": "机器人开发 - 测试消息"}
    },
    secret="pD6SEfuw75zNo74qxT5ZPb"
)
engine.send_feishu(
    webhook_url="https://open.feishu.cn/open-apis/bot/v2/hook/c476ec1f-6037-4e52-ad65-843e16201456",
    message={
        "msg_type": "text",
        "content": {"text": "机器人开发 - 测试消息"}
    },
    secret="pD6SEfuw75zNo74qxT5ZPb"
)
engine.send_feishu(
    webhook_url="https://open.feishu.cn/open-apis/bot/v2/hook/c476ec1f-6037-4e52-ad65-843e16201456",
    message={
        "msg_type": "text",
        "content": {"text": "机器人开发 - 测试消息"}
    },
    secret="pD6SEfuw75zNo74qxT5ZPb"
)

sleep(3)

engine.close()
