# %% [markdown]
# ## TODOs 待办事项
#
# - 飞书风控提醒会重复发两次, 需要修复
# - ordersysid 也需要衍生出 vt_ordersysid, 并将其实际用于整个策略内
# - TickData 需要包含 当日均价 (average price)
# - run_scheduler.bat 无法持续运行两个及以上的周期
# - PositionData 需要添加新的字段: open_avg_price, used_margin, open_cost, open_amount, open_volume
# - CTP报单后使用调试模式检查回报数据, 记录好每个字段的实际样子
# - 监控品种参数化, 可以通过 JSON 配置文件排除掉特定品种
